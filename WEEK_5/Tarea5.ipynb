# %% [markdown]
# Tarea III
#
# AdvNNs
#
# 21 de noviembre de 2025
#
# Resumen
#
# El objetivo de esta tarea es cerrar el proyecto final. Por favor suba sus soluciones en un archivo comprimido a Classroom antes del 2 de diciembre.

# %% [markdown]
# Problema 1
#
# Describa los siguientes puntos clave de su proyecto (puede agregar algunos gráficos a su respuesta):
#
# a) Identifique qué tan bien funciona su modelo con sus datos. ¿Cuáles son los puntos fuertes de su modelo?
#
# b) ¿Cuáles son las debilidades de su modelo? Haga un plan para tratarlas.
#
# c) Imagine algunas posibles líneas de trabajo futuras aumentando la dificultad del problema. ¿Qué tan bien escalará su solución/modelo al escenario más complejo? ¿Cuáles son las posibles ventajas/desventajas de su modelo para ese caso?
#
# d) Haga una revisión SOTA (estado del arte) sobre el problema que está resolviendo y el modelo que está utilizando. Identifique cómo otros artículos abordan el problema. ¿Qué tan original/útil es su propuesta en comparación?

# %% [markdown]
# Problema 2
#
# Haga un resumen breve de su problema completo, conjunto de datos y modelo, así como los mejores resultados y todas las acciones/decisiones/suposiciones que tomó.
